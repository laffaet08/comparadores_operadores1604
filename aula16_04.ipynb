# %% [markdown]
# <a href="https://colab.research.google.com/github/laffaet08/comparadores_operadores1604/blob/main/aula16_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("8 é maior que 6:", 8 > 6)
print("8 é menor que 7:", 8 < 7)
print(8==7)
print(10>=10)
print(10 < 10)
print(10 <= 10)
# Out:
# 8 é maior que 6: True
# 8 é menor que 7: False
# False
# True
# False
# True

# %%
#atividade001
idade = int(input("digite sua idade"))
idade2 = int(input("digite sua idade"))
print(idade == idade2)
print(idade != idade2)
print(idade > idade2)
print(idade >= idade2)
print(idade < idade2)
print(idade <= idade2)
# Out:
# digite sua idade 66
# digite sua idade 77
# False
# True
# False
# False
# True
# True

# %%
#atividade002
idade = int(input("digite sua idade"))
convite = input("tem convite? (sim/nao)")
resultado = (idade >= 18) and (convite == "sim")
print(resultado)
# Out:
# digite sua idade22
# tem convite? (sim/nao)sim
# True

# %%
#atividade003
usuario = input("digite seu usuario")
senha = input("digite sua senha")
resultado = (usuario == "admin") and (senha == "1234")
print(resultado)
# Out:
# digite seu usuarioadmin
# digite sua senha1234
# True

# %%
#atividade004
VIP = input("voce é cliente VIP? sim ou nao")
valor = float(input("digite o valor da compra"))
resultado = ( VIP == "sim") or ( valor> 100)
print(resultado)
# Out:
# voce é cliente VIP? sim ou nao nao
# digite o valor da compra 103
# True

# %%
#atividade005
dia = input("digite o dia da semana: ")
resultado = not(dia == "segunda" or dia =="terca" or dia == "quarta" or dia == "quinta" or dia == "sexta")
print(resultado)
# Out:
# digite o dia da semana: sabado
# True
